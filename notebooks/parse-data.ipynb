# %% [markdown]
# ### Check the music theory dataset is parsable

# %%
import pandas as pd

# %%
pd.read_csv('../data/music-theory-dataset-100.csv', sep=',')
# Out:
#                                  title             artist        genre  \
# 0                            Let It Be        The Beatles          Pop
# 1                     Hotel California             Eagles         Rock
# 2                           Wonderwall              Oasis         Rock
# 3                  Sweet Child O' Mine      Guns N' Roses         Rock
# 4                 The Sound of Silence  Simon & Garfunkel         Folk
# ..                                 ...                ...          ...
# 95                         Bad Romance          Lady Gaga          Pop
# 96                  Mr. Tambourine Man          Bob Dylan         Folk
# 97                       Back in Black              AC/DC         Rock
# 98  Nocturne in E-flat Major Op.9 No.2    Frédéric Chopin    Classical
# 99             Swing Low Sweet Chariot        Traditional  Traditional
#
#          key  tempo_bpm time_signature  \
# 0    C major         76            4/4
# ...
